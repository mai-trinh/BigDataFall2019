# %%
from pytrends.request import TrendReq
import matplotlib.pyplot as plt
import pandas as pd 
import geopandas as gpd
from descartes import PolygonPatch
import plotly.plotly as py
import plotly.graph_objs as go

# Set the filepath and load in map shapefile
fp = "/Users/macboook/desktop/answer_BigData/Big_Data_Final_Project/countries_shp/countries.shp"
map_df = gpd.read_file(fp)

# check GEOdataframe
# print (map_df.head())

# set the index of the data set to be name of countries 
map_df.set_index('NAME',inplace = True)
# map_df.head()

# Log in to Google  
pytrends = TrendReq(hl='en-US', tz=360)

# The list of keywords that we want to search through 
kw_list = ['buy flight ticket']

# Build payload
pytrends.build_payload(kw_list, cat=0, timeframe='today 5-y', geo='', gprop='')
interest_by_region_df = pytrends.interest_by_region()
interest_by_region_df = interest_by_region_df.cumsum()

data_for_map = interest_by_region_df
# print (data_for_map.loc['Bahamas']['flight ticket'])
# print (data_for_map.index.tolist())

# join the geodataframe with the cleaned up dataframe
merged = map_df.join(data_for_map) # success !!!
# print (merged)

# set a variable that will call whatever column we want to visualise on the map
variable = 'buy flight ticket'

# set the range for the choropleth
vmin, vmax = 0, data_for_map.values.max()

# create figure and axes for Matplotlib
fig, ax = plt.subplots(1, figsize=(8, 4))  

# create map
merged.plot(column=variable, cmap='Spectral', linewidth=0.2, ax=ax, edgecolor='0.8')

# remove the axis
ax.axis('off')

# add a title
ax.set_title('Popularity of "buy flight ticket" google searches ', fontdict={'fontsize': '15', 'fontweight' : '3'})

# create an annotation for the data source
ax.annotate('Source: GoogleTrends' ,xy=(0.1, .08),  xycoords='figure fraction', horizontalalignment='left', verticalalignment='top', fontsize=12, color='#555555')

# Create colorbar as a legend
sm = plt.cm.ScalarMappable(cmap='Spectral', norm=plt.Normalize(vmin=vmin, vmax=vmax))

# empty array for the data range
sm._A = []

# add the colorbar to the figure
cbar = fig.colorbar(sm)

# export image 
fig.savefig("map_export_buy_flight_ticket.png", dpi=300)
# Out:
# /Applications/anaconda3/lib/python3.7/site-packages/matplotlib/colors.py:512: RuntimeWarning:
#
# invalid value encountered in less

# %%
# The list of keywords that we want to search through 
kw_list = ['book hotel']

# Build payload
pytrends.build_payload(kw_list, cat=0, timeframe='today 5-y', geo='', gprop='')
interest_by_region_df = pytrends.interest_by_region()
interest_by_region_df = interest_by_region_df.cumsum()

data_for_map = interest_by_region_df
# print (data_for_map.loc['Bahamas']['flight ticket'])
# print (data_for_map.index.tolist())

# join the geodataframe with the cleaned up dataframe
merged = map_df.join(data_for_map) # success !!!
# print (merged)

# set a variable that will call whatever column we want to visualise on the map
variable = 'book hotel'

# set the range for the choropleth
vmin, vmax = 0, data_for_map.values.max()

# create figure and axes for Matplotlib
fig, ax = plt.subplots(1, figsize=(8, 4))  

# create map
merged.plot(column=variable, cmap='Spectral', linewidth=0.2, ax=ax, edgecolor='0.8')

# remove the axis
ax.axis('off')

# add a title
ax.set_title('Popularity of "book hotel" google searches ', fontdict={'fontsize': '15', 'fontweight' : '3'})

# create an annotation for the data source
ax.annotate('Source: GoogleTrends' ,xy=(0.1, .08),  xycoords='figure fraction', horizontalalignment='left', verticalalignment='top', fontsize=12, color='#555555')

# Create colorbar as a legend
sm = plt.cm.ScalarMappable(cmap='Spectral', norm=plt.Normalize(vmin=vmin, vmax=vmax))

# empty array for the data range
sm._A = []

# add the colorbar to the figure
cbar = fig.colorbar(sm)

# export image 
fig.savefig("map_export_book_hotel.png", dpi=300)

# %%
# The list of keywords that we want to search through 
kw_list = ['travel plan']

# Build payload
pytrends.build_payload(kw_list, cat=0, timeframe='today 5-y', geo='', gprop='')

interest_by_region_df = pytrends.interest_by_region()

interest_by_region_df = interest_by_region_df.cumsum()

data_for_map = interest_by_region_df
# print (data_for_map.loc['Bahamas']['flight ticket'])
# print (data_for_map.index.tolist())

# join the geodataframe with the cleaned up dataframe
merged = map_df.join(data_for_map) # success !!!
# print (merged)

# set a variable that will call whatever column we want to visualise on the map
variable = 'travel plan'

# set the range for the choropleth
vmin, vmax = 0, data_for_map.values.max()

# create figure and axes for Matplotlib
fig, ax = plt.subplots(1, figsize=(8, 4))  

# create map
merged.plot(column=variable, cmap='Spectral', linewidth=0.2, ax=ax, edgecolor='0.8')

# remove the axis
ax.axis('off')

# add a title
ax.set_title('Popularity of "travel plan" google searches ', fontdict={'fontsize': '15', 'fontweight' : '3'})

# create an annotation for the data source
ax.annotate('Source: GoogleTrends' ,xy=(0.1, .08),  xycoords='figure fraction', horizontalalignment='left', verticalalignment='top', fontsize=12, color='#555555')

# Create colorbar as a legend
sm = plt.cm.ScalarMappable(cmap='Spectral', norm=plt.Normalize(vmin=vmin, vmax=vmax))

# empty array for the data range
sm._A = []

# add the colorbar to the figure
cbar = fig.colorbar(sm)

# export image 
fig.savefig("map_export_travel_plan.png", dpi=300)

# %%
# Travel hashtags 
# Interest Over Time 

from pytrends.request import TrendReq
import matplotlib.pyplot as plt

# NOTES ON PyTrends:
# - Google Trends gives you a search interest indexp

# Log in to Google  
pytrends = TrendReq(hl='en-US', tz=360)

# The list of keywords that we want to search through 
kw_list_1 = ['tourist','travelpics','vacation','wanderlust','traveling']

# Build payload
pytrends.build_payload(kw_list_1, cat=0, timeframe='2012-01-01 2018-12-30', geo='', gprop='')
interest_over_time_df_1 = pytrends.interest_over_time()
interest_over_time_df_1 = interest_over_time_df_1.cumsum()
print (interest_over_time_df_1)

# The list of keywords that we want to search through 
kw_list_2 = ['rtw','ttot','travel','traveltuesday']

# Build payload
pytrends.build_payload(kw_list_2, cat=0, timeframe='2012-01-01 2018-12-30', geo='', gprop='')

# Testing 
# print (pytrends.interest_over_time()) # this returns pandas.Dataframe
interest_over_time_df_2 = pytrends.interest_over_time()
interest_over_time_df_2 = interest_over_time_df_2.cumsum()

print (interest_over_time_df_2)
# Out:
#            tourist travelpics vacation wanderlust traveling isPartial
# date
# 2012-01-01      43          0       93          2        14     False
# 2012-02-01      85          0      178         14        29         0
# 2012-03-01     129          0      259         22        44         0
# 2012-04-01     174          0      334         26        59         0
# 2012-05-01     221          0      415         30        74         0
# 2012-06-01     266          0      503         45        89         0
# 2012-07-01     312          0      595         57       104         0
# 2012-08-01     357          0      668         67       119         0
# 2012-09-01     397          0      725         73       134         0
# 2012-10-01     435          0      779         77       148         0
# 2012-11-01     469          0      836         81       162         0
# 2012-12-01     504          0      911         85       176         0
# 2013-01-01     543          0      996         90       191         0
# 2013-02-01     582          0     1076         94       206         0
# 2013-03-01     625          0     1154         98       222         0
# 2013-04-01     666          0     1228        102       238         0
# 2013-05-01     711          0     1301        106       253         0
# 2013-06-01     757          0     1386        110       269         0
# 2013-07-01     802          0     1473        115       284         0
# 2013-08-01     847          0     1545        120       299         0
# 2013-09-01     888          0     1601        124       314         0
# 2013-10-01     927          0     1653        127       328         0
# 2013-11-01     963          0     1709        130       342         0
# 2013-12-01     998          0     1782        133       356         0
# 2014-01-01    1038          0     1867        137       371         0
# 2014-02-01    1078          0     1943        140       387         0
# 2014-03-01    1119          0     2018        144       403         0
# 2014-04-01    1163          0     2086        148       419         0
# 2014-05-01    1208          0     2156        152       436         0
# 2014-06-01    1253          0     2238        157       453         0
# ...            ...        ...      ...        ...       ...       ...
# 2016-07-01    2371          0     4149        254       881         0
# 2016-08-01    2418          0     4224        258       898         0
# 2016-09-01    2463          0     4287        262       916         0
# 2016-10-01    2507          0     4347        265       933         0
# 2016-11-01    2547          0     4407        268       950         0
# 2016-12-01    2589          0     4489        272       967         0
# 2017-01-01    2635          0     4573        276       986         0
# 2017-02-01    2680          0     4652        280      1005         0
# 2017-03-01    2725          0     4728        284      1024         0
# 2017-04-01    2773          0     4801        288      1043         0
# 2017-05-01    2825          0     4874        292      1062         0
# 2017-06-01    2878          0     4961        296      1081         0
# 2017-07-01    2931          0     5049        300      1100         0
# 2017-08-01    2981          0     5121        304      1117         0
# 2017-09-01    3031          0     5177        308      1134         0
# 2017-10-01    3078          0     5233        312      1154         0
# 2017-11-01    3123          0     5294        315      1171         0
# 2017-12-01    3170          0     5377        318      1188         0
# 2018-01-01    3218          0     5456        322      1206         0
# 2018-02-01    3263          0     5527        325      1223         0
# 2018-03-01    3311          0     5601        329      1242         0
# 2018-04-01    3362          0     5683        333      1261         0
# 2018-05-01    3416          0     5761        336      1280         0
# 2018-06-01    3469          0     5846        340      1299         0
# 2018-07-01    3524          0     5928        344      1318         0
# 2018-08-01    3577          0     6003        348      1336         0
# 2018-09-01    3625          0     6064        355      1353         0
# 2018-10-01    3672          0     6120        362      1370         0
# 2018-11-01    3718          0     6182        367      1387         0
# 2018-12-01    3768          0     6266        371      1404         0
#
# [84 rows x 6 columns]
#            rtw ttot travel traveltuesday isPartial
# date
# 2012-01-01   0    0     96             0     False
# 2012-02-01   0    0    186             0         0
# 2012-03-01   0    0    272             0         0
# 2012-04-01   0    0    360             0         0
# 2012-05-01   0    0    451             0         0
# 2012-06-01   0    0    546             0         0
# 2012-07-01   0    0    646             0         0
# 2012-08-01   0    0    739             0         0
# 2012-09-01   0    0    824             0         0
# 2012-10-01   0    0    901             0         0
# 2012-11-01   0    0    975             0         0
# 2012-12-01   0    0   1048             0         0
# 2013-01-01   0    0   1141             0         0
# 2013-02-01   0    0   1226             0         0
# 2013-03-01   0    0   1312             0         0
# 2013-04-01   0    0   1398             0         0
# 2013-05-01   0    0   1485             0         0
# 2013-06-01   0    0   1575             0         0
# 2013-07-01   0    0   1669             0         0
# 2013-08-01   0    0   1759             0         0
# 2013-09-01   0    0   1837             0         0
# 2013-10-01   0    0   1914             0         0
# 2013-11-01   0    0   1987             0         0
# 2013-12-01   0    0   2061             0         0
# 2014-01-01   0    0   2150             0         0
# 2014-02-01   0    0   2238             0         0
# 2014-03-01   0    0   2320             0         0
# 2014-04-01   0    0   2403             0         0
# 2014-05-01   0    0   2487             0         0
# 2014-06-01   0    0   2577             0         0
# ...         ..  ...    ...           ...       ...
# 2016-07-01   0    0   4625             0         0
# 2016-08-01   0    0   4706             0         0
# 2016-09-01   0    0   4783             0         0
# 2016-10-01   0    0   4855             0         0
# 2016-11-01   0    0   4928             0         0
# 2016-12-01   0    0   4998             0         0
# 2017-01-01   0    0   5088             0         0
# 2017-02-01   0    0   5175             0         0
# 2017-03-01   0    0   5262             0         0
# 2017-04-01   0    0   5345             0         0
# 2017-05-01   0    0   5430             0         0
# 2017-06-01   0    0   5519             0         0
# 2017-07-01   0    0   5607             0         0
# 2017-08-01   0    0   5694             0         0
# 2017-09-01   0    0   5772             0         0
# 2017-10-01   0    0   5850             0         0
# 2017-11-01   0    0   5927             0         0
# 2017-12-01   0    0   6002             0         0
# 2018-01-01   0    0   6091             0         0
# 2018-02-01   0    0   6176             0         0
# 2018-03-01   0    0   6262             0         0
# 2018-04-01   0    0   6346             0         0
# 2018-05-01   0    0   6429             0         0
# 2018-06-01   0    0   6517             0         0
# 2018-07-01   0    0   6607             0         0
# 2018-08-01   0    0   6695             0         0
# 2018-09-01   0    0   6772             0         0
# 2018-10-01   0    0   6845             0         0
# 2018-11-01   0    0   6917             0         0
# 2018-12-01   0    0   6990             0         0
#
# [84 rows x 5 columns]

# %%
import plotly 
import plotly.plotly as py
import plotly.graph_objs as go

# Log in 
plotly.tools.set_credentials_file(username='maitrinh', api_key='RJnp3zCnBq5cMKQtZZfR')

# Add data
year = ['2012', '2013', '2014', '2015', '2016', '2017', '2018']

# Data for each category 
tourist = interest_over_time_df_1['tourist'].tolist()
travelpics = interest_over_time_df_1['travelpics'].tolist()
vacation = interest_over_time_df_1['vacation'].tolist()
wanderlust = interest_over_time_df_1['wanderlust'].tolist()
traveling = interest_over_time_df_1['traveling'].tolist()
rtw = interest_over_time_df_2['rtw'].tolist()
ttot = interest_over_time_df_2['ttot'].tolist()
travel = interest_over_time_df_2['travel'].tolist()
traveltuesday = interest_over_time_df_2['traveltuesday'].tolist()


# Create and style traces
trace0 = go.Scatter(
    x = year,
    y = tourist,
    name = 'tourist',
    line = dict(
        color = ('rgb(255,105,180)'), #pink
        width = 3)
)
trace1 = go.Scatter(
    x = year,
    y = travelpics,
    name = 'travelpics',
    line = dict(
        color = ('rgb(255,215,0)'), #yellow
        width = 3,)
)
trace2 = go.Scatter(
    x = year,
    y = vacation,
    name = 'vacation',
    line = dict(
        color = ('rgb(65,105,225)'), #green
        width = 3) # dash options include 'dash', 'dot', and 'dashdot'
)
trace3 = go.Scatter(
    x = year,
    y = traveling,
    name = 'traveling',
    line = dict(
        color = ('rgb(255,69,0)'),#red 
        width = 3)
)
trace4 = go.Scatter(
    x = year,
    y = wanderlust,
    name = 'wanderlust',
    line = dict(
        color = ('rgb(30,144,255)'),
        width = 3)
)
trace5 = go.Scatter(
    x = year,
    y = rtw,
    name = 'rtw',
    line = dict(
        color = ('rgb(72,209,204)'),
        width = 3)
)
trace6 = go.Scatter(
    x = year,
    y = ttot,
    name = 'ttot',
    line = dict(
        color = ('rgb(128,0,128)'),
        width = 3)
)
trace7 = go.Scatter(
    x = year,
    y = travel,
    name = 'travel',
    line = dict(
        color = ('rgb(154,205,50)'),
        width = 3)
)
trace8 = go.Scatter(
    x = year,
    y = traveltuesday,
    name = 'traveltuesday',
    line = dict(
        color = ('rgb(47,79,79)'),
        width = 3)
)
 
data = [trace0, trace1, trace2, trace3, trace4, trace5, trace6, trace7, trace8]

# Edit the layout
layout = dict(title = 'Popular travel terms on Twitter reflected on Google Trends searches',
              xaxis = dict(title = 'Year'),
              yaxis = dict(title = 'Search Frequency'),
              )

fig = dict(data=data, layout=layout)
py.iplot(fig, filename='popular_term_line')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~maitrinh/6.embed" height="525px" width="100%"></iframe>

# %%
import plotly 
import plotly.plotly as py
import plotly.graph_objs as go
from pytrends.request import TrendReq
import matplotlib.pyplot as plt

# NOTES ON PyTrends:
# - Google Trends gives you a search interest indexp

# Log in to Google  
pytrends = TrendReq(hl='en-US', tz=360)

# Log in plotly
plotly.tools.set_credentials_file(username='maitrinh', api_key='RJnp3zCnBq5cMKQtZZfR')

# The list of keywords that we want to search through 
kw_list_1 = ['tourist','travelpics','vacation','wanderlust','traveling']

# Build payload
pytrends.build_payload(kw_list_1, cat=0, timeframe='2019-03-30 2019-04-30', geo='', gprop='')
iot_df_1 = pytrends.interest_over_time()
iot_df_1 = iot_df_1.cumsum()
print (iot_df_1)


# The list of keywords that we want to search through 
kw_list_2 = ['rtw','ttot','travel','traveltuesday']

# Build payload
pytrends.build_payload(kw_list_2, cat=0, timeframe='2019-03-30 2019-04-30', geo='', gprop='')

# Testing 
# print (pytrends.interest_over_time()) # this returns pandas.Dataframe
iot_df_2 = pytrends.interest_over_time()
iot_df_2 = iot_df_2.cumsum()

print (iot_df_2)
# Out:
#            tourist travelpics vacation wanderlust traveling isPartial
# date
# 2019-03-30      59          0       90          5        20     False
# 2019-03-31     121          0      190         10        43         0
# 2019-04-01     179          0      283         14        67         0
# 2019-04-02     236          0      372         19        93         0
# 2019-04-03     293          0      454         23       120         0
# 2019-04-04     354          0      542         27       148         0
# 2019-04-05     415          0      622         31       178         0
# 2019-04-06     476          0      697         35       207         0
# 2019-04-07     545          0      787         39       239         0
# 2019-04-08     608          0      873         43       269         0
# 2019-04-09     670          0      956         47       297         0
# 2019-04-10     731          0     1042         51       324         0
# 2019-04-11     790          0     1128         55       351         0
# 2019-04-12     849          0     1211         59       378         0
# 2019-04-13     912          0     1289         63       404         0
# 2019-04-14     974          0     1376         67       430         0
# 2019-04-15    1038          0     1462         71       457         0
# 2019-04-16    1105          0     1547         75       482         0
# 2019-04-17    1170          0     1631         79       507         0
# 2019-04-18    1236          0     1718         83       532         0
# 2019-04-19    1305          0     1796         88       556         0
# 2019-04-20    1376          0     1876         93       578         0
# 2019-04-21    1446          0     1955         98       601         0
# 2019-04-22    1510          0     2046        102       626         0
# 2019-04-23    1572          0     2137        106       651         0
# 2019-04-24    1635          0     2220        110       675         0
# 2019-04-25    1694          0     2306        114       699         0
# 2019-04-26    1752          0     2389        118       720         0
# 2019-04-27    1815          0     2468        122       742         0
# 2019-04-28    1882          0     2561        127       766         0
# 2019-04-29    1946          0     2649        131       792         0
#            rtw ttot travel traveltuesday isPartial
# date
# 2019-03-30   0    0     81             0     False
# 2019-03-31   0    0    171             0         0
# 2019-04-01   0    0    266             0         0
# 2019-04-02   0    0    361             0         0
# 2019-04-03   0    0    456             0         0
# 2019-04-04   0    0    548             0         0
# 2019-04-05   0    0    634             0         0
# 2019-04-06   0    0    715             0         0
# 2019-04-07   0    0    805             0         0
# 2019-04-08   0    0    901             0         0
# 2019-04-09   0    0    995             0         0
# 2019-04-10   0    0   1095             0         0
# 2019-04-11   0    0   1189             0         0
# 2019-04-12   0    0   1278             0         0
# 2019-04-13   0    0   1358             0         0
# 2019-04-14   0    0   1442             0         0
# 2019-04-15   0    0   1535             0         0
# 2019-04-16   0    0   1627             0         0
# 2019-04-17   0    0   1717             0         0
# 2019-04-18   0    0   1805             0         0
# 2019-04-19   0    0   1889             0         0
# 2019-04-20   0    0   1967             0         0
# 2019-04-21   0    0   2048             0         0
# 2019-04-22   0    0   2142             0         0
# 2019-04-23   0    0   2238             0         0
# 2019-04-24   0    0   2330             0         0
# 2019-04-25   0    0   2422             0         0
# 2019-04-26   0    0   2511             0         0
# 2019-04-27   0    0   2596             0         0
# 2019-04-28   0    0   2688             0         0
# 2019-04-29   0    0   2785             0         0

# %%
tourist_sum = sum(iot_df_1["tourist"].tolist())
travelpics_sum = sum(iot_df_1["travelpics"].tolist())
vacation_sum = sum(iot_df_1["vacation"].tolist())
wanderlust_sum = sum(iot_df_1["wanderlust"].tolist())
traveling_sum = sum(iot_df_1["traveling"].tolist())

rtw_sum = sum(iot_df_2["rtw"].tolist())
ttot_sum = sum(iot_df_2["ttot"].tolist())
travel_sum = sum(iot_df_2["travel"].tolist())
traveltuesday_sum = sum(iot_df_2["traveltuesday"].tolist())

total_sum = tourist_sum + travelpics_sum + vacation_sum + wanderlust_sum + traveling_sum + rtw_sum + ttot_sum + travel_sum + traveltuesday_sum
# print (total_sum)

tourist = tourist_sum / total_sum
travelpics = travelpics_sum / total_sum
vacation = vacation_sum / total_sum
wanderlust = wanderlust_sum / total_sum
traveling = traveling_sum / total_sum

rtw = rtw_sum / total_sum
ttot = ttot_sum / total_sum
travel = travel_sum / total_sum
traveltuesday = traveltuesday_sum / total_sum

# %%
# Pie chart 
labels = ['tourist','travelpics','vacation','wanderlust','traveling','rtw','ttot','travel','traveltuesday']
values = [tourist, travelpics, vacation, wanderlust, traveling, rtw, ttot, travel, traveltuesday]

trace = go.Pie(labels=labels, values=values,hoverinfo='label', 
               textfont=dict(size=20))

layout = dict(title = 'Popular travel terms on Twitter reflected on Google Trends searches')

fig = dict(data=[trace], layout=layout)
py.iplot(fig, filename='popular_term_pie')

# py.iplot([trace], filename='terms_pie_chart')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~maitrinh/12.embed" height="525px" width="100%"></iframe>
